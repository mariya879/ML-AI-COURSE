# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
import pandas as pd

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew

# %%
#loading of csvs

# %%
df=pd.read_csv('diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               657 non-null    float64
#  1   Glucose                   763 non-null    float64
#  2   BloodPressure             733 non-null    float64
#  3   SkinThickness             541 non-null    float64
#  4   Insulin                   768 non-null    float64
#  5   BMI                       757 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    float64
# dtypes: float64(8), int64(1)
# memory usage: 54.1 KB

# %% [markdown]
# FINDING NULL VALUES OF EACH ROW

# %%
#0 should be considered as null now

# %%
df.replace(0, np.nan, inplace=True)

# %%
nan_counts = df.isnull().sum()

print(nan_counts)
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   657.000000  763.000000     733.000000     541.000000  394.000000
# mean      4.494673  121.686763      72.405184      29.153420  155.548223
# std       3.217291   30.535641      12.382158      10.476982  118.775855
# min       1.000000   44.000000      24.000000       7.000000   14.000000
# 25%       2.000000   99.000000      64.000000      22.000000   76.250000
# 50%       4.000000  117.000000      72.000000      29.000000  125.000000
# 75%       7.000000  141.000000      80.000000      36.000000  190.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age  Outcome
# count  757.000000                768.000000  768.000000    268.0
# mean    32.457464                  0.471876   33.240885      1.0
# std      6.924988                  0.331329   11.760232      0.0
# ...

# %% [markdown]
# PLOTTING EACH COLUMN OF THE DATA FOR IDENTIFYING THE DISTRIBUTION OF THE DATA

# %%
# Plot histograms for numerical columns and count plots for categorical columns
for col in df.columns:
    if df[col].dtype == 'float64' or df[col].dtype == 'int64':
        plt.figure(figsize=(8, 6))
        sns.histplot(df[col], bins=30, kde=True)
        plt.title(f'Distribution of {col}')
        plt.xlabel(col)
        plt.ylabel('Frequency')
        plt.show()
    else:
        plt.figure(figsize=(8, 6))
        sns.countplot(x=col, data=df)
        plt.title(f'Count Plot of {col}')
        plt.xlabel(col)
        plt.ylabel('Count')
        plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# FOR CATEGORICAL VALUE MODE IS SUITABLE METHOD FOR FILLING THE NAN VALUES

# %%
df['Outcome'].fillna(df['Outcome'].mode().iloc[0], inplace=True)  # Fill NaN with mode of 'Outcome' column

# %% [markdown]
# FOR NUMERICAL VALUES

# %% [markdown]
# IF THE DISTRIBUTION IS LEFTLY SKEWED REPLCE WITH MEAN AND IF RIGHT REPLCE WITH MEDIAN

# %%
numerical_cols = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']

# %%
for col in numerical_cols:
    df[col].fillna(df[col].mean(), inplace=True)  # Fill NaN with median
   
print(df.isnull().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64
